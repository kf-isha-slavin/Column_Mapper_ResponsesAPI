# %% [markdown]
# # Set-Up Code

# %%
OPENAI_API_KEY = '*********'
OPENAI_PROJECT="*********"
OPENAI_ORG="*********"

# %%
# from utils.envs import OPENAI_API_KEY
import os
import base64
from typing import List, Dict
from openai import OpenAI
import openai
import glob
import pprint
import tqdm
import numpy as np
import json
import tiktoken
import pandas as pd
import re
import ast
import time
from datetime import datetime

# %% [markdown]
# ### Initialize OpenAI Client

# %%
client = OpenAI(api_key=OPENAI_API_KEY, project=OPENAI_PROJECT, organization=OPENAI_ORG)

# %% [markdown]
# ### Test that I can use Assistants & Responses API

# %%
# test that i can prompt a model

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello! How can I use OpenAI's API to classify job descriptions?"}
    ]
)   

print(response.choices[0].message.content)
# Out:
# To classify job descriptions using OpenAI's API, you can follow these general steps:
#
# 1. Obtain access to OpenAI's API: Sign up for an account on OpenAI's platform and get access to the API keys required to make requests.
#
# 2. Prepare your job description data: Gather a dataset of job descriptions that you want to classify. Ensure that the data is properly formatted and ready for analysis.
#
# 3. Choose a suitable model: Determine which model provided by OpenAI's API would be best suited for your classification task. OpenAI offers several models, such as GPT-3 or DALL-E, that can be used for text analysis tasks.
#
# 4. Make API requests: Use the API keys provided by OpenAI to make requests to the chosen model with your job descriptions as input data. The model will generate predictions based on the input data.
#
# 5. Evaluate the results: Review the output of the model to see how well it has classified the job descriptions. You may need to fine-tune the model or adjust parameters to improve performance.
#
# 6. Iterate: Continue refining your model and testing it with additional job descriptions until you achieve the desired level of accuracy.
#
# Remember to always abide by OpenAI's terms of service and guidelines when using their API. Let me know if you need any further assistance with any specific steps!

# %%
response = client.responses.create(
    model="gpt-5",
    input = "Hello! How can I use OpenAI's API to classify job descriptions?",
    instructions = "You are a helpful assistant."
)

print(response.output[1].content[0].text)
# Out:
# Great question. There are three common ways to classify job descriptions with OpenAI’s API, depending on your data and constraints:
#
# 1) Zero/few-shot classification with structured JSON output (fastest to start)
# - Use a small reasoning model like o4-mini or a lightweight model like gpt-4o-mini.
# - Constrain the output with a JSON Schema so you always get machine-parseable labels.
# - Add a few in-prompt examples for tricky edge cases.
# - Set temperature=0 for deterministic results.
#
# Python example (single-call classifier with strict JSON output)
# - Replace YOUR_JOB_TEXT with your JD text.
#
# from openai import OpenAI
# import json
#
# client = OpenAI()
#
# job_schema = {
#   "name": "job_classification",
#   "schema": {
#     "type": "object",
#     "additionalProperties": False,
#     "properties": {
#       "job_family": {
#         "type": "string",
#         "enum": [
#           "Software Engineering","Data Science","Product Management",
#           "Sales","Marketing","Design","Human Resources",
#           "Finance","Operations","Customer Support","Other"
#         ]
#       },
#       "seniority": {
#         "type": "string",
#         "enum": ["Intern","Junior","Mid","Senior","Lead","Manager","Director","VP","C-level","Unclear"]
#       },
#       "employment_type": {
#         "type": "string",
#         "enum": ["Full-time","Part-time","Contract","Temporary","Internship","Unknown"]
#       },
#       "work_arrangement": {
#         "type": "string",
#         "enum": ["Onsite","Remote","Hybrid","Unknown"]
#       },
#       "locations": {
#         "type": "array",
#         "items": {"type": "string"},
#         "description": "Cities or countries explicitly mentioned"
#       },
#       "skills": {
#         "type": "array",
#         "items": {"type": "string"},
#         "maxItems": 15
#       },
#       "abstain": {"type": "boolean"},
#       "abstain_reason": {"type": "string"}
#     },
#     "required": ["job_family","seniority","employment_type","work_arrangement","skills","abstain"]
#   },
#   "strict": True
# }
#
# jd_text = """YOUR_JOB_TEXT"""
#
# resp = client.responses.create(
#   model="o4-mini",
#   temperature=0,
#   input=[
#     {
#       "role": "system",
#       "content": (
#         "You are a precise classifier for job descriptions. "
#         "Choose the best labels from the schema. "
#         "If the description is ambiguous or lacks evidence for a label, set abstain=true and explain in abstain_reason. "
#         "Extract only explicit skills mentioned or obvious from title (e.g., 'Python', 'AWS', 'B2B sales'). "
#         "Do not invent locations or skills. Output must satisfy the JSON schema exactly."
#       )
#     },
#     {
#       "role": "user",
#       "content": f"Classify this job description:\n\n{jd_text}"
#     }
#   ],
#   response_format={"type": "json_schema", "json_schema": job_schema}
# )
#
# result = json.loads(resp.output_text)
# print(result)
#
# JavaScript (Node.js) equivalent
#
# import OpenAI from "openai";
# const client = new OpenAI();
#
# const jobSchema = {
#   name: "job_classification",
#   schema: {
#     type: "object",
#     additionalProperties: false,
#     properties: {
#       job_family: {
#         type: "string",
#         enum: [
#           "Software Engineering","Data Science","Product Management",
#           "Sales","Marketing","Design","Human Resources",
#           "Finance","Operations","Customer Support","Other"
#         ],
#       },
#       seniority: {
#         type: "string",
#         enum: ["Intern","Junior","Mid","Senior","Lead","Manager","Director","VP","C-level","Unclear"]
#       },
#       employment_type: {
#         type: "string",
#         enum: ["Full-time","Part-time","Contract","Temporary","Internship","Unknown"]
#       },
#       work_arrangement: {
#         type: "string",
#         enum: ["Onsite","Remote","Hybrid","Unknown"]
#       },
#       locations: { type: "array", items: { type: "string" } },
#       skills: { type: "array", items: { type: "string" }, maxItems: 15 },
#       abstain: { type: "boolean" },
#       abstain_reason: { type: "string" },
#     },
#     required: ["job_family","seniority","employment_type","work_arrangement","skills","abstain"]
#   },
#   strict: true
# };
#
# const jdText = `YOUR_JOB_TEXT`;
#
# const response = await client.responses.create({
#   model: "o4-mini",
#   temperature: 0,
#   input: [
#     {
#       role: "system",
#       content:
#         "You are a precise classifier for job descriptions. Choose the best labels from the schema. " +
#         "If the description is ambiguous, set abstain=true and explain. Extract only explicit skills. " +
#         "Output must satisfy the JSON schema exactly."
#     },
#     {
#       role: "user",
#       content: `Classify this job description:\n\n${jdText}`
#     }
#   ],
#   response_format: { type: "json_schema", json_schema: jobSchema }
# });
#
# const result = JSON.parse(response.output_text);
# console.log(result);
#
# Tips for the prompt
# - Put clear label definitions in the system message. If you have a custom taxonomy, define each label in one line with examples.
# - Add 2–5 short few-shot examples for edge cases right before the user message.
# - Include an “Other/Unknown” and an “abstain” path to reduce hallucinations.
# - Use temperature=0 for consistent output.
#
# Batching many descriptions
# - Loop over your list and call responses.create per item.
# - For large volumes, consider async batching and backoff on rate limits. Keep context short.
#
# 2) Taxonomy matching with embeddings (best for stable label sets and large volumes)
# - Pre-embed your taxonomy labels (and optionally label descriptions) with text-embedding-3-large.
# - Embed each job description, compute cosine similarity to all labels, and select the top label(s).
# - Optionally, let a small model verify among the top 3 candidates if you need extra accuracy.
#
# Python sketch
#
# from openai import OpenAI
# import numpy as np
#
# client = OpenAI()
#
# def embed(texts):
#     res = client.embeddings.create(model="text-embedding-3-large", input=texts)
#     return [np.array(d.embedding, dtype=np.float32) for d in res.data]
#
# def cosine(a,b): return float(np.dot(a,b) / (np.linalg.norm(a)*np.linalg.norm(b)))
#
# # 1) Pre-embed your taxonomy (run once and cache/store)
# labels = [
#   ("Software Engineering", "Builds software; coding; backend/frontend; cloud; CI/CD; APIs"),
#   ("Data Science", "Statistics; ML; modeling; Python; SQL; experimentation"),
#   ("Sales", "Prospecting; pipeline; quota; CRM; closing"),
#   # ...
# ]
# label_texts = [f"{name}: {desc}" for name,desc in labels]
# label_embs = embed(label_texts)
#
# # 2) Classify a job description
# jd = """YOUR_JOB_TEXT"""
# jd_emb = embed([jd])[0]
# scores = [cosine(jd_emb, e) for e in label_embs]
# top_idx = int(np.argmax(scores))
# top_label, _ = labels[top_idx]
# top_score = scores[top_idx]
#
# # Optional: multi-label if above threshold
# selected = [labels[i][0] for i,s in sorted(enumerate(scores), key=lambda x: -x[1]) if s >= 0.80][:3]
#
# print(top_label, top_score, selected)
#
# Hybrid pattern
# - Use embeddings to get top 3 candidate labels, then prompt the model: “Choose exactly one of: [A, B, C]” with a strict schema. This improves precision and keeps latency/cost low.
#
# 3) Fine-tuning (best when you have thousands of labeled JDs and a fixed taxonomy)
# - Train a small model (e.g., gpt-4o-mini) on many labeled examples to maximize consistency and reduce per-call prompt size.
# - Prepare JSONL with input → label pairs. Keep inputs concise (title + 2–4 key bullets) if possible.
# - Keep an “Unknown/Other” label in the dataset.
# - After fine-tuning, call the fine-tuned model the same way as above, ideally still with structured outputs.
#
# Example training row (conceptual)
# {"messages":[
#   {"role":"system","content":"Classify job descriptions into one of: Software Engineering, Data Science, Sales, ..."},
#   {"role":"user","content":"Title: Senior Backend Engineer\nBullets: Go, microservices, Kubernetes, AWS, on-call\n"},
#   {"role":"assistant","content":"{\"job_family\":\"Software Engineering\",\"seniority\":\"Senior\"}"}
# ]}
#
# What to classify for job descriptions
# - Job family/department
# - Seniority level
# - Employment type and work arrangement
# - Location(s)
# - Skills/technologies (limit list length)
# - Optional: industry, domain, clearance, language requirements
# - Add “abstain” and “Unknown/Other” to handle ambiguity
#
# Quality tips
# - Define each label in plain language with 1–2 examples in the system prompt.
# - Use strict JSON schema to avoid malformed outputs.
# - Temperature=0 and concise prompts increase determinism.
# - Evaluate on a labeled validation set; iterate on label definitions and few-shots.
# - For long JDs, truncate to the most relevant sections (title, responsibilities, requirements) or summarize first.
#
# If you share your exact taxonomy and an example job description, I can tailor the schema and a ready-to-run prompt for you.

# %%
client.vector_stores.list()
# Out:
# SyncCursorPage[VectorStore](data=[VectorStore(id='vs_69025034e2fc81918fdcad91301db0cf', created_at=1761759285, file_counts=FileCounts(cancelled=0, completed=1, failed=0, in_progress=0, total=1), last_active_at=1761759310, metadata={}, name='column_mapper_v1', object='vector_store', status='completed', usage_bytes=9184, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68fdb1fa7e688191a6a4f690441695ea', created_at=1761456634, file_counts=FileCounts(cancelled=0, completed=5, failed=0, in_progress=0, total=5), last_active_at=1761456685, metadata={}, name='job_classifier_GPT_isha', object='vector_store', status='completed', usage_bytes=5282022, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68fba18f05408191853bfea00e219bc4', created_at=1761321359, file_counts=FileCounts(cancelled=0, completed=5, failed=0, in_progress=0, total=5), last_active_at=1761321615, metadata={}, name='job_classifier_gpt_no_aliases', object='vector_store', status='completed', usage_bytes=4355190, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68fb9a22e8cc8191947ee19dd49d417c', created_at=1761319459, file_counts=FileCounts(cancelled=0, completed=5, failed=0, in_progress=0, total=5), last_active_at=1761319864, metadata={}, name='job_classifier_gpt', object='vector_store', status='completed', usage_bytes=5282032, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68f62c38e3348191a93f191cb8b5fc39', created_at=1760963641, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1760963642, metadata={}, name='360-standard Knowledge Base - 2025-10-20T12:34:00.839Z', object='vector_store', status='completed', usage_bytes=1394591, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68f296e26d188191a01d0a4f1019489e', created_at=1760728802, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1760729083, metadata={}, name='kf360_kb_faqs_gpt-4.1_20251017', object='vector_store', status='completed', usage_bytes=1394591, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68e7ad1a0b1c81919cbb4a3763bb5d39', created_at=1760013594, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1760013595, metadata={}, name='360-standard Knowledge Base - 2025-10-09T12:39:53.660Z', object='vector_store', status='completed', usage_bytes=1364978, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68deaf9a2b08819181c2e5d1aca8d6bb', created_at=1759424410, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1759426452, metadata={}, name='kf_360_kb_faqs_gpt-4.1_20251002', object='vector_store', status='completed', usage_bytes=1364978, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68dbf2119b4c8191a6a6c4c7fab3fe6d', created_at=1759244817, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1759244821, metadata={}, name='360-standard Knowledge Base - 2025-09-30T15:06:57.184Z', object='vector_store', status='completed', usage_bytes=1327827, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68dbe052373081919195957a533617b1', created_at=1759240274, file_counts=FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2), last_active_at=1759240278, metadata={}, name='360-standard Knowledge Base - 2025-09-30T13:51:13.750Z', object='vector_store', status='completed', usage_bytes=570762, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68dab96f93c08191887543dfdcd16619', created_at=1759164783, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1759164872, metadata={}, name='kf_360_kb_faqs_gpt-4.1_20250929', object='vector_store', status='completed', usage_bytes=1363852, ex ...

# %% [markdown]
# # Read in Competitor Data

# %%
df_competitor = pd.read_excel('./../Files/Competitor/All Countries - 2025 Submission_WTW_test 1.xlsx')
print(df_competitor.shape)
df_competitor.head()
# Out:
# (9, 198)
#   Country Code  Case Number  Reports to Case Number          Area/City Code  \
# 0          NaN          NaN                     NaN  APAC, EMEA, LATAM ONLY
# 1          AUT          1.0                     NaN                   AT001
# 2          AUT          2.0                     NaN                   AT001
# 3          AUT          3.0                     NaN                   AT001
# 4          AUT          4.0                     NaN                   AT001
#
#                  Postal/ZIP Code  Unique Incumbent Identifier  \
# 0  APAC, EMEA, CANADA, U.S. ONLY                          NaN
# 1                            NaN                     183019.0
# 2                            NaN                     183038.0
# 3                            NaN                     183064.0
# 4                            NaN                     183087.0
#
#    Department Name             Internal Position Title  \
# 0              NaN                                 NaN
# 1              0.0  Retail Operative (Sales Assistant)
# 2              0.0                          Supervisor
# 3              0.0  Retail Operative (Sales Assistant)
# 4              0.0  Retail Operative (Sales Assistant)
#
#    Internal Grade/Level/Band           Paterson Grade  ...  \
# 0                        NaN  SUB-SAHARAN AFRICA ONLY  ...
# 1                        1.0                      NaN  ...
# 2                        2.0                      NaN  ...
# 3                        1.0                      NaN  ...
# 4                        1.0                      NaN  ...
#
#   Number of Shares/Units Granted.2 Grant Structure (SO and PP plans only).2  \
# 0                              NaN                   APAC, EMEA, LATAM ONLY
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
#
#   Long-Term Incentive Plan Type.3 Long-Term Incentive Plan Number.3  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
#
#    Grant Date.3  Grant Price Currency.3 Grant Price Per Share/Unit.3  \
# 0           NaN                     NaN                          NaN
# 1           NaN                     NaN                          NaN
# 2           NaN                     NaN                          NaN
# 3           NaN                     NaN                          NaN
# 4           NaN                     NaN                          NaN
#
#    Accounting Value per Share/Unit of Award.3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Number of Shares/Units Granted.3 Grant Structure (SO and PP plans only).3
# 0                              NaN                   APAC, EMEA, LATAM ONLY
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
#
# [5 rows x 198 columns]

# %%
df_comp_columns = df_competitor.columns.tolist()
print(len(df_comp_columns))
print(df_comp_columns[:10])
print(df_comp_columns[-10:])
# Out:
# 198
# ['Country Code', 'Case Number', 'Reports to Case Number', 'Area/City Code', 'Postal/ZIP Code', 'Unique Incumbent Identifier', 'Department Name', 'Internal Position Title', 'Internal Grade/Level/Band', 'Paterson Grade']
# ['Number of Shares/Units Granted.2', 'Grant Structure (SO and PP plans only).2', 'Long-Term Incentive Plan Type.3', 'Long-Term Incentive Plan Number.3', 'Grant Date.3', 'Grant Price Currency.3', 'Grant Price Per Share/Unit.3', 'Accounting Value per Share/Unit of Award.3', 'Number of Shares/Units Granted.3', 'Grant Structure (SO and PP plans only).3']

# %% [markdown]
# # PROMPTING

# %% [markdown]
# ### System Instructions

# %%
system_instructions = f"""
You are an expert data-mapping model trained on Korn Ferry’s column architecture.

You have access to the file `fixed_KF_template.txt`, which contains three columns:
- **KF_Column_Title**: the canonical Korn Ferry column name
- **Description**: a detailed explanation of what that column represents
- **Status**: one of "Required", "Optional", or "If Applicable"

Your task is to map input column names from another dataset to the most semantically similar columns in Korn Ferry’s architecture.

You will receive a list of {len(df_comp_columns)} input column names.

For each input column name, you must:
1. Compare it to all KF_Column_Titles and their Descriptions.
2. Select the **three most relevant Korn Ferry columns** based on meaning, function, or usage similarity.
3. Return your output in **strict JSON format** as follows:

{{
  "input_column": "<input_column_1_name>",
  "predictions": {{
      "matched_KF_column_1": "<prediction_1_of_KF_Column_Title>",
      "matched_KF_column_2": "<prediction_2_of_KF_Column_Title>",
      "matched_KF_column_3": "<prediction_3_of_KF_Column_Title>"
  }},
  "input_column": "<input_column_2_name>",
  "predictions": {{
      "matched_KF_column_1": "<prediction_1_of_KF_Column_Title>",
      "matched_KF_column_2": "<prediction_2_of_KF_Column_Title>",
      "matched_KF_column_3": "<prediction_3_of_KF_Column_Title>"
  }},
  ...
}}

Guidelines:
- Always return **three** matches per input column — no fewer.
- Use both title and description context from Korn Ferry’s architecture to infer matches.
- If unsure, select the closest conceptual matches based on meaning.
- Do **not** include commentary, explanations, or text outside the JSON output.
- Preserve exact spelling and casing of all KF_Column_Title values.
"""

# %%
user_query = f"""
You are given the following {len(df_comp_columns)} input column names that need to be mapped to Korn Ferry’s column architecture:

{df_comp_columns}

Please map each input column to its **three closest** KF_Column_Titles as described in your system instructions.
"""

# %%
print(len(df_comp_columns))
df_comp_columns
# Out:
# 198
# ['Country Code',
#  'Case Number',
#  'Reports to Case Number',
#  'Area/City Code',
#  'Postal/ZIP Code',
#  'Unique Incumbent Identifier',
#  'Department Name',
#  'Internal Position Title',
#  'Internal Grade/Level/Band',
#  'Paterson Grade',
#  'Employee Status',
#  'Hierarchical Title',
#  'Education Level',
#  'Livello',
#  'Expatriate Status',
#  'Expatriate Pay Country',
#  'Employment Contract',
#  'Gender',
#  'Origin Code',
#  'Ethnic Origin',
#  'Date of Birth',
#  'Date of Hire',
#  'Primary Medium',
#  'Year of Entry into Business/Industry',
#  'Date of Contract Termination',
#  'Basic Hours Worked Per Week',
#  'Date of Appointment',
#  'Function Code',
#  'Discipline Code',
#  'Career Level',
#  'Incumbent Survey Grade',
#  'PEMP GRADING - Factor 1',
#  'PEMP GRADING - Factor 2',
#  'PEMP GRADING - Factor 3',
#  'PEMP GRADING - Factor 4',
#  'PEMP GRADING - Factor 5',
#  'Job Matching Comments',
#  'Same Job Match',
#  'Business Unit Name',
#  'Business Unit Primary Industry',
#  'Currency of Financial Job Impact Data',
#  'Incumbent Revenue Responsibility',
#  'Number of Employees Supervised (Direct + Indirect)',
#  'Overtime Eligibility',
#  'Exempt/Nonexempt',
#  'Union/Nonunion',
#  'Corporate/Noncorporate',
#  'Corporate Reporting Level',
#  'Country Reporting Level',
#  'Board/Executive Committee Membership',
#  'Geographic Scope',
#  'Number of Sites/Properties',
#  'Retail Store/Site Classification',
#  'Store Revenue',
#  'Currency of Pay Elements',
#  'Annual Base Salary',
#  'Base Salary - Hourly Rate',
#  'Annual Base Salary Midpoint',
#  'Previous Year Annual Base Salary',
#  'Monthly Base Salary',
#  'Base Salary Number of Months',
#  'Bonus 14th',
#  'Fixed Foreign Source Income',
#  'Guaranteed Fringe Benefits (Part of Base Salary)',
#  'Overtime Compensation Type',
#  'Guaranteed Shift/Overtime Compensation',
#  'Legal Bonus',
#  'Total Cost of Employment (T.C.O.E.)',
#  'Annual General Bonus',
#  "Annual Director's Fees",
#  'Annual Medical Aid',
#  'Annual Life / Accident Insurance',
#  'Christmas Bonus',
#  'Consolidated Fixed Cash Allowance',
#  "Child's Education Allowance per child (as per company policy)",
#  "Child's Education Allowance - Number of Children Covered",
#  'Clothing/Uniform Allowance',
#  'Eligible for Grocery Allowance',
#  'Grocery Allowance',
#  'Housing Allowance',
#  'Length of Service Allowance',
#  'Location Allowance',
#  'Meal Allowance',
#  'Medical Allowance',
#  'National Holiday Bonus',
#  'Perfect Attendance Premium',
#  'Professional/License Allowance',
#  'Punctuality and Attendance Premium',
#  'Representation Allowance',
#  'Rice Allowance',
#  'Eligible for Short-Term Savings Fund',
#  'Short-Term Savings Fund',
#  'Telecommunication Allowance',
#  'Transportation Allowance',
#  'Vacation Allowance',
#  'Vacation Bonus',
#  'Other Fixed Cash Allowances',
#  'Other Fixed Cash Allowance Type',
#  'Best Productive Practices Allowance (Monthly Amount)',
#  'Hazardous Conditions Allowance (Monthly Amount)',
#  'Health Hazard Allowance (Monthly Amount)',
#  'Loss Cashier Fund (Monthly Amount)',
#  'Meal Allowance (Monthly Amount)',
#  'Shift Allowance (Monthly Amount)',
#  'Standby Allowance (Monthly Amount)',
#  'Eligible for Performance Bonus',
#  'Target Performance Bonus % of Annual Base Salary',
#  'Target Performance Bonus (Annual Amount)',
#  'Maximum Performance Bonus % of Annual Base Salary',
#  'Target Performance Bonus % of Annual Guaranteed Pay',
#  'Maximum Performance Bonus % of Annual Guaranteed Pay',
#  'Maximum Performance Bonus Amount',
#  'Actual Performance Bonus Amount',
#  'Actual Performance Bonus - Immediate Payment in Cash',
#  'Actual Performance Bonus - Immediate Payment in Shares',
#  'Actual Performance Bonus - Compulsory Cash Deferral',
#  'Actual Performance Bonus - Compulsory Share Deferral',
#  'Eligible for Sales Incentive Plan',
#  'Target Goal-Based Sales Incentive % of Annual Base Salary',
#  'Target Goal-Based Sales Incentive (Annual Amount)',
#  'Actual Goal-Based Sales Incentive Amount',
#  'Actual Commission Amount',
#  'Actual Discretionary Bonus Amount',
#  'Eligible for Production Bonus',
#  'Target Production Bonus (Annual Amount)',
#  'Actual Production Bonus (Annual Amount)',
#  'Variable Foreign Source Income',
#  'Target Other Annual Incentives',
#  'Actual Other Annual Incentives',
#  'Other Annual Incentive Type',
#  'Profit-Sharing - Guaranteed',
#  'Eligible for Profit-Sharing',
#  'Target Profit-Sharing Amount',
#  'Profit-Sharing - Voluntary',
#  'Profit-Sharing - Legal/Mandatory',
#  'Net Total Annual Compensation',
#  'Car Benefit Type',
#  'Car Benefit Eligibility Criteria',
#  'Car Make and Model',
#  'Currency of Car Benefit Amounts',
#  'Car Purchase Cost',
#  'Annual Car Leasing Cost',
#  'Car Lease Type',
#  'Annual Car Allowance Amount',
#  'Car Annual Imputed Tax Value',
#  'Flexible Benefit Amount',
#  'Eligible for Retirement Plan',
#  'Pension Plan Type',
#  'Annual Pension Contribution Amount',
#  'Organization Contribution to Pension Plan/Retirement',
#  'Organization Contribution to Health Benefits',
#  'Other Insurance Plans - Risk Insurance',
#  'Value of Vacation Ticket Reimbursement',
#  'Club Membership Eligibility',
#  'Club Annual Fee',
#  'Flexible Perquisites Eligibility',
#  'Flexible Perquisites Amount',
#  'Financial Counseling Eligibility',
#  'Financial Counseling Amount',
#  'Other Perquisites Eligibility',
#  'Other Perquisite Amount',
#  'Other Perquisite Type',
#  'Eligible for Long-Term Incentive',
#  'New Hire Grant Receiver',
#  'Value of New Hire Grant',
#  'Value of New Hire Grant Currency',
#  'Long-Term Incentive Plan Type',
#  'Long-Term Incentive Plan Number',
#  'Grant Date',
#  'Grant Price Currency',
#  'Grant Price Per Share/Unit',
#  'Accounting Value per Share/Unit of Award',
#  'Number of Shares/Units Granted',
#  'Grant Structure (SO and PP plans only)',
#  'Long-Term Incentive Plan Type.1',
#  'Long-Term Incentive Plan Number.1',
#  'Grant Date.1',
#  'Grant Price Currency.1',
#  'Grant Price Per Share/Unit.1',
#  'Accounting Value per Share/Unit of Award.1',
#  'Number of Shares/Units Granted.1',
#  'Grant Structure (SO and PP plans only).1',
#  'Long-Term Incentive Plan Type.2',
#  'Long-Term Incentive Plan Number.2',
#  'Grant Date.2',
#  'Grant Price Currency.2',
#  'Grant Price Per Share/Unit.2',
#  'Accounting Value per Share/Unit of Award.2',
#  'Number of Shares/Units Granted.2',
#  'Grant Structure (SO and PP plans only).2',
#  'Long-Term Incentive Plan Type.3',
#  'Long-Term Incentive Plan Number.3',
#  'Grant Date.3',
#  'Grant Price Currency.3',
#  'Grant Price Per Share/Unit.3',
#  'Accounting Value per Share/Unit of Award.3',
#  'Number of Shares/Units Granted.3',
#  'Grant Structure (SO and PP plans only).3']

# %% [markdown]
# # Testing the prompts

# %%
start_time = time.time()
response_0 = client.responses.create(input=user_query,
                                    instructions=system_instructions,
                                    model="gpt-5",
                                    tools=[{"type": "file_search",
                                            "vector_store_ids": ["vs_69025034e2fc81918fdcad91301db0cf"],
                                            }]
                                    )
end_time = time.time()

# %%
latency = end_time - start_time
print(f"Response time: {latency} seconds")

# %%
output = response_0.output[-1].content[-1].text
print(type(output))
print(output)
# Out:
# <class 'str'>
# {
#   "citation": "  ",
#   "mappings": [
#     {
#       "input_column": "Country Code",
#       "predictions": {
#         "matched_KF_column_1": "Country",
#         "matched_KF_column_2": "Currency",
#         "matched_KF_column_3": "Employee Work Location / Zip/Postal Code"
#       }
#     },
#     {
#       "input_column": "Case Number",
#       "predictions": {
#         "matched_KF_column_1": "Employee ID",
#         "matched_KF_column_2": "Korn Ferry Reference  Job Code",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Reports to Case Number",
#       "predictions": {
#         "matched_KF_column_1": "Manager Employee  ID",
#         "matched_KF_column_2": "Employee ID",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Area/City Code",
#       "predictions": {
#         "matched_KF_column_1": "Employee Work Location / Zip/Postal Code",
#         "matched_KF_column_2": "Country",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Postal/ZIP Code",
#       "predictions": {
#         "matched_KF_column_1": "Employee Work Location / Zip/Postal Code",
#         "matched_KF_column_2": "Country",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Unique Incumbent Identifier",
#       "predictions": {
#         "matched_KF_column_1": "Employee ID",
#         "matched_KF_column_2": "Manager Employee  ID",
#         "matched_KF_column_3": "Korn Ferry Reference  Job Code"
#       }
#     },
#     {
#       "input_column": "Department Name",
#       "predictions": {
#         "matched_KF_column_1": "Department",
#         "matched_KF_column_2": "Legal Entity / Business Unit",
#         "matched_KF_column_3": "Function Code  (not required if Ref. Job Code is provided  in column O)"
#       }
#     },
#     {
#       "input_column": "Internal Position Title",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Job Title",
#         "matched_KF_column_2": "Korn Ferry Reference  Job Code",
#         "matched_KF_column_3": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)"
#       }
#     },
#     {
#       "input_column": "Internal Grade/Level/Band",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Grade / Band",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Korn Ferry Total Points"
#       }
#     },
#     {
#       "input_column": "Paterson Grade",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Grade / Band",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Korn Ferry Total Points"
#       }
#     },
#     {
#       "input_column": "Employee Status",
#       "predictions": {
#         "matched_KF_column_1": "Executive/Non-Executive Indicator (E / N)",
#         "matched_KF_column_2": "Weekly Hours Worked",
#         "matched_KF_column_3": "Expat"
#       }
#     },
#     {
#       "input_column": "Hierarchical Title",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Job Title",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "Education Level",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Grade / Band",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Year of Birth"
#       }
#     },
#     {
#       "input_column": "Livello",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Grade / Band",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Korn Ferry Total Points"
#       }
#     },
#     {
#       "input_column": "Expatriate Status",
#       "predictions": {
#         "matched_KF_column_1": "Expat",
#         "matched_KF_column_2": "Country",
#         "matched_KF_column_3": "Currency"
#       }
#     },
#     {
#       "input_column": "Expatriate Pay Country",
#       "predictions": {
#         "matched_KF_column_1": "Country",
#         "matched_KF_column_2": "Currency",
#         "matched_KF_column_3": "Expat"
#       }
#     },
#     {
#       "input_column": "Employment Contract",
#       "predictions": {
#         "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "Gender",
#       "predictions": {
#         "matched_KF_column_1": "Gender",
#         "matched_KF_column_2": "Year of Birth",
#         "matched_KF_column_3": "Executive/Non-Executive Indicator (E / N)"
#       }
#     },
#     {
#       "input_column": "Origin Code",
#       "predictions": {
#         "matched_KF_column_1": "Country",
#         "matched_KF_column_2": "Expat",
#         "matched_KF_column_3": "Gender"
#       }
#     },
#     {
#       "input_column": "Ethnic Origin",
#       "predictions": {
#         "matched_KF_column_1": "Country",
#         "matched_KF_column_2": "Gender",
#         "matched_KF_column_3": "Year of Birth"
#       }
#     },
#     {
#       "input_column": "Date of Birth",
#       "predictions": {
#         "matched_KF_column_1": "Year of Birth",
#         "matched_KF_column_2": "Gender",
#         "matched_KF_column_3": "Employee ID"
#       }
#     },
#     {
#       "input_column": "Date of Hire",
#       "predictions": {
#         "matched_KF_column_1": "Year of Hire",
#         "matched_KF_column_2": "Employee ID",
#         "matched_KF_column_3": "Department"
#       }
#     },
#     {
#       "input_column": "Primary Medium",
#       "predictions": {
#         "matched_KF_column_1": "Function Code  (not required if Ref. Job Code is provided  in column O)",
#         "matched_KF_column_2": "Department",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Year of Entry into Business/Industry",
#       "predictions": {
#         "matched_KF_column_1": "Year of Hire",
#         "matched_KF_column_2": "Employee  Grade / Band",
#         "matched_KF_column_3": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)"
#       }
#     },
#     {
#       "input_column": "Date of Contract Termination",
#       "predictions": {
#         "matched_KF_column_1": "Year of Hire",
#         "matched_KF_column_2": "Executive/Non-Executive Indicator (E / N)",
#         "matched_KF_column_3": "Employee ID"
#       }
#     },
#     {
#       "input_column": "Basic Hours Worked Per Week",
#       "predictions": {
#         "matched_KF_column_1": "Weekly Hours Worked",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Date of Appointment",
#       "predictions": {
#         "matched_KF_column_1": "Year of Hire",
#         "matched_KF_column_2": "Employee ID",
#         "matched_KF_column_3": "Department"
#       }
#     },
#     {
#       "input_column": "Function Code",
#       "predictions": {
#         "matched_KF_column_1": "Function Code  (not required if Ref. Job Code is provided  in column O)",
#         "matched_KF_column_2": "Subfunction Code  (not required if Ref. Job Code is provided in column O)",
#         "matched_KF_column_3": "Korn Ferry Reference  Job Code"
#       }
#     },
#     {
#       "input_column": "Discipline Code",
#       "predictions": {
#         "matched_KF_column_1": "Subfunction Code  (not required if Ref. Job Code is provided in column O)",
#         "matched_KF_column_2": "Function Code  (not required if Ref. Job Code is provided  in column O)",
#         "matched_KF_column_3": "Korn Ferry Reference  Job Code"
#       }
#     },
#     {
#       "input_column": "Career Level",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_2": "Employee  Grade / Band",
#         "matched_KF_column_3": "Korn Ferry Total Points"
#       }
#     },
#     {
#       "input_column": "Incumbent Survey Grade",
#       "predictions": {
#         "matched_KF_column_1": "Employee  Grade / Band",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Korn Ferry Total Points"
#       }
#     },
#     {
#       "input_column": "PEMP GRADING - Factor 1",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Total Points",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "PEMP GRADING - Factor 2",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Total Points",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "PEMP GRADING - Factor 3",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Total Points",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "PEMP GRADING - Factor 4",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Total Points",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "PEMP GRADING - Factor 5",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Total Points",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "Job Matching Comments",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Reference  Job Code",
#         "matched_KF_column_2": "Korn Ferry Total Points",
#         "matched_KF_column_3": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)"
#       }
#     },
#     {
#       "input_column": "Same Job Match",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Reference  Job Code",
#         "matched_KF_column_2": "Korn Ferry Total Points",
#         "matched_KF_column_3": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)"
#       }
#     },
#     {
#       "input_column": "Business Unit Name",
#       "predictions": {
#         "matched_KF_column_1": "Legal Entity / Business Unit",
#         "matched_KF_column_2": "Department",
#         "matched_KF_column_3": "Employee Work Location / Zip/Postal Code"
#       }
#     },
#     {
#       "input_column": "Business Unit Primary Industry",
#       "predictions": {
#         "matched_KF_column_1": "Function Code  (not required if Ref. Job Code is provided  in column O)",
#         "matched_KF_column_2": "Subfunction Code  (not required if Ref. Job Code is provided in column O)",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Currency of Financial Job Impact Data",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Country",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Incumbent Revenue Responsibility",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_2": "Employee  Grade / Band",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Number of Employees Supervised (Direct + Indirect)",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_2": "Employee  Grade / Band",
#         "matched_KF_column_3": "Executive/Non-Executive Indicator (E / N)"
#       }
#     },
#     {
#       "input_column": "Overtime Eligibility",
#       "predictions": {
#         "matched_KF_column_1": "Weekly Hours Worked",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Exempt/Nonexempt",
#       "predictions": {
#         "matched_KF_column_1": "Weekly Hours Worked",
#         "matched_KF_column_2": "Executive/Non-Executive Indicator (E / N)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "Union/Nonunion",
#       "predictions": {
#         "matched_KF_column_1": "Legal Entity / Business Unit",
#         "matched_KF_column_2": "Department",
#         "matched_KF_column_3": "Employee Work Location / Zip/Postal Code"
#       }
#     },
#     {
#       "input_column": "Corporate/Noncorporate",
#       "predictions": {
#         "matched_KF_column_1": "Executive/Non-Executive Indicator (E / N)",
#         "matched_KF_column_2": "Legal Entity / Business Unit",
#         "matched_KF_column_3": "Employee  Job Title"
#       }
#     },
#     {
#       "input_column": "Corporate Reporting Level",
#       "predictions": {
#         "matched_KF_column_1": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_2": "Employee  Grade / Band",
#         "matched_KF_column_3": "Executive/Non-Executive Indicator (E / N)"
#       }
#     },
#     {
#       "input_column": "Country Reporting Level",
#       "predictions": {
#         "matched_KF_column_1": "Country",
#         "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#         "matched_KF_column_3": "Employee  Grade / Band"
#       }
#     },
#     {
#       "input_column": "Board/Executive Committee Membership",
#       "predictions": {
#         "matched_KF_column_1": "Executive/Non-Executive Indicator (E / N)",
#         "matched_KF_column_2": "Employee  Job Title",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Geographic Scope",
#       "predictions": {
#         "matched_KF_column_1": "Country",
#         "matched_KF_column_2": "Employee Work Location / Zip/Postal Code",
#         "matched_KF_column_3": "Legal Entity / Business Unit"
#       }
#     },
#     {
#       "input_column": "Number of Sites/Properties",
#       "predictions": {
#         "matched_KF_column_1": "Legal Entity / Business Unit",
#         "matched_KF_column_2": "Country",
#         "matched_KF_column_3": "Employee Work Location / Zip/Postal Code"
#       }
#     },
#     {
#       "input_column": "Retail Store/Site Classification",
#       "predictions": {
#         "matched_KF_column_1": "Legal Entity / Business Unit",
#         "matched_KF_column_2": "Function Code  (not required if Ref. Job Code is provided  in column O)",
#         "matched_KF_column_3": "Subfunction Code  (not required if Ref. Job Code is provided in column O)"
#       }
#     },
#     {
#       "input_column": "Store Revenue",
#       "predictions": {
#         "matched_KF_column_1": "Legal Entity / Business Unit",
#         "matched_KF_column_2": "Function Code  (not required if Ref. Job Code is provided  in column O)",
#         "matched_KF_column_3": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)"
#       }
#     },
#     {
#       "input_column": "Currency of Pay Elements",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Country",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual Base Salary",
#       "predictions": {
#         "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Salary Structure Midpoint",
#         "matched_KF_column_3": "Fixed Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Base Salary - Hourly Rate",
#       "predictions": {
#         "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Weekly Hours Worked",
#         "matched_KF_column_3": "Fixed Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual Base Salary Midpoint",
#       "predictions": {
#         "matched_KF_column_1": "Salary Structure Midpoint",
#         "matched_KF_column_2": "Salary Structure Minimum",
#         "matched_KF_column_3": "Salary Structure Maximum"
#       }
#     },
#     {
#       "input_column": "Previous Year Annual Base Salary",
#       "predictions": {
#         "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Salary Structure Midpoint",
#         "matched_KF_column_3": "Fixed Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Monthly Base Salary",
#       "predictions": {
#         "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Salary Structure Midpoint"
#       }
#     },
#     {
#       "input_column": "Base Salary Number of Months",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Bonus 14th",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "All Other Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Fixed Foreign Source Income",
#       "predictions": {
#         "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Currency",
#         "matched_KF_column_3": "Country"
#       }
#     },
#     {
#       "input_column": "Guaranteed Fringe Benefits (Part of Base Salary)",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Overtime Compensation Type",
#       "predictions": {
#         "matched_KF_column_1": "Weekly Hours Worked",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Guaranteed Shift/Overtime Compensation",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Weekly Hours Worked"
#       }
#     },
#     {
#       "input_column": "Legal Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "All Other Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Total Cost of Employment (T.C.O.E.)",
#       "predictions": {
#         "matched_KF_column_1": "Total Package (Annual full-time equivalent)",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual General Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Annual Director's Fees",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Executive/Non-Executive Indicator (E / N)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual Medical Aid",
#       "predictions": {
#         "matched_KF_column_1": "Medical Aid Contribution (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual Life / Accident Insurance",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Total Package (Annual full-time equivalent)",
#         "matched_KF_column_3": "Medical Aid Contribution (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Christmas Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Consolidated Fixed Cash Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Child's Education Allowance per child (as per company policy)",
#       "predictions": {
#         "matched_KF_column_1": "Dependent Education Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Child's Education Allowance - Number of Children Covered",
#       "predictions": {
#         "matched_KF_column_1": "Dependent Education Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Clothing/Uniform Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Eligible for Grocery Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Meal Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Grocery Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Meal Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Housing Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Housing Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Length of Service Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Location Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Housing Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Transportation / Commuting Allowance (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Meal Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Meal Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Medical Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Medical Aid Contribution (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "All Other Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "National Holiday Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Perfect Attendance Premium",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Fixed Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Professional/License Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Punctuality and Attendance Premium",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Fixed Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Representation Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Transportation / Commuting Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Rice Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Meal Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Eligible for Short-Term Savings Fund",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Total Pension/Provident Fund (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Short-Term Savings Fund",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Total Pension/Provident Fund (Annual full-time equivalent)",
#         "matched_KF_column_3": "Medical Aid Contribution (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Telecommunication Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Telecommunication Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Transportation Allowance",
#       "predictions": {
#         "matched_KF_column_1": "Transportation / Commuting Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Vacation Allowance",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Vacation Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Other Fixed Cash Allowances",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Other Fixed Cash Allowance Type",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Best Productive Practices Allowance (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Fixed Payments (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Hazardous Conditions Allowance (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Health Hazard Allowance (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Loss Cashier Fund (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Meal Allowance (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "Meal Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Shift Allowance (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Weekly Hours Worked"
#       }
#     },
#     {
#       "input_column": "Standby Allowance (Monthly Amount)",
#       "predictions": {
#         "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Eligible for Performance Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Target Performance Bonus % of Annual Base Salary",
#       "predictions": {
#         "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Target Performance Bonus (Annual Amount)",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Maximum Performance Bonus % of Annual Base Salary",
#       "predictions": {
#         "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Target Performance Bonus % of Annual Guaranteed Pay",
#       "predictions": {
#         "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Maximum Performance Bonus % of Annual Guaranteed Pay",
#       "predictions": {
#         "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Maximum Performance Bonus Amount",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Actual Performance Bonus Amount",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Actual Performance Bonus - Immediate Payment in Cash",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Currency"
#       }
#     },
#     {
#       "input_column": "Actual Performance Bonus - Immediate Payment in Shares",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Actual Fair Value of Total LTI Granted"
#       }
#     },
#     {
#       "input_column": "Actual Performance Bonus - Compulsory Cash Deferral",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Actual Performance Bonus - Compulsory Share Deferral",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Eligible for Sales Incentive Plan",
#       "predictions": {
#         "matched_KF_column_1": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Target Goal-Based Sales Incentive % of Annual Base Salary",
#       "predictions": {
#         "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Target Goal-Based Sales Incentive (Annual Amount)",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Actual Goal-Based Sales Incentive Amount",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Actual Commission Amount",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Actual Discretionary Bonus Amount",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Eligible for Production Bonus",
#       "predictions": {
#         "matched_KF_column_1": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Target Production Bonus (Annual Amount)",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Actual Production Bonus (Annual Amount)",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Variable Foreign Source Income",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Currency",
#         "matched_KF_column_3": "Country"
#       }
#     },
#     {
#       "input_column": "Target Other Annual Incentives",
#       "predictions": {
#         "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Actual Other Annual Incentives",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Other Annual Incentive Type",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Profit-Sharing - Guaranteed",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Eligible for Profit-Sharing",
#       "predictions": {
#         "matched_KF_column_1": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#       }
#     },
#     {
#       "input_column": "Target Profit-Sharing Amount",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Target Short-term Variable Payment  (% of Base Salary)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Profit-Sharing - Voluntary",
#       "predictions": {
#         "matched_KF_column_1": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#         "matched_KF_column_3": "All Other Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Profit-Sharing - Legal/Mandatory",
#       "predictions": {
#         "matched_KF_column_1": "Fixed Payments (Annual full-time equivalent)",
#         "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term  Variable  Payment  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Net Total Annual Compensation",
#       "predictions": {
#         "matched_KF_column_1": "Total Package (Annual full-time equivalent)",
#         "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#         "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Car Benefit Type",
#       "predictions": {
#         "matched_KF_column_1": "Car Eligibility  (Y/N)",
#         "matched_KF_column_2": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Car Benefit Eligibility Criteria",
#       "predictions": {
#         "matched_KF_column_1": "Car Eligibility  (Y/N)",
#         "matched_KF_column_2": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Car Make and Model",
#       "predictions": {
#         "matched_KF_column_1": "Car Eligibility  (Y/N)",
#         "matched_KF_column_2": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Currency of Car Benefit Amounts",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Car Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Car Purchase Cost",
#       "predictions": {
#         "matched_KF_column_1": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual Car Leasing Cost",
#       "predictions": {
#         "matched_KF_column_1": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "Car Eligibility  (Y/N)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Car Lease Type",
#       "predictions": {
#         "matched_KF_column_1": "Car Eligibility  (Y/N)",
#         "matched_KF_column_2": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Annual Car Allowance Amount",
#       "predictions": {
#         "matched_KF_column_1": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "Car Eligibility  (Y/N)",
#         "matched_KF_column_3": "Currency"
#       }
#     },
#     {
#       "input_column": "Car Annual Imputed Tax Value",
#       "predictions": {
#         "matched_KF_column_1": "Car Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Flexible Benefit Amount",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
# ...
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Other Insurance Plans - Risk Insurance",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "Total Package (Annual full-time equivalent)",
#         "matched_KF_column_3": "Medical Aid Contribution (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Value of Vacation Ticket Reimbursement",
#       "predictions": {
#         "matched_KF_column_1": "Transportation / Commuting Allowance (Annual full-time equivalent)",
#         "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "All Other Allowances (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Club Membership Eligibility",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Executive/Non-Executive Indicator (E / N)"
#       }
#     },
#     {
#       "input_column": "Club Annual Fee",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Flexible Perquisites Eligibility",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Car Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Flexible Perquisites Amount",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Financial Counseling Eligibility",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Executive/Non-Executive Indicator (E / N)"
#       }
#     },
#     {
#       "input_column": "Financial Counseling Amount",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Other Perquisites Eligibility",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Other Perquisite Amount",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Other Perquisite Type",
#       "predictions": {
#         "matched_KF_column_1": "Other Benefits and Allowances (Annual full-time equivalent)",
#         "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#         "matched_KF_column_3": "Total Package (Annual full-time equivalent)"
#       }
#     },
#     {
#       "input_column": "Eligible for Long-Term Incentive",
#       "predictions": {
#         "matched_KF_column_1": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "New Hire Grant Receiver",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Value of New Hire Grant",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Value of New Hire Grant Currency",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Type",
#       "predictions": {
#         "matched_KF_column_1": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Number",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Date",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Price Currency",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Grant Price Per Share/Unit",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Accounting Value per Share/Unit of Award",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Target Fair Value of Total LTI Granted as % of Base Salary",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Number of Shares/Units Granted",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Structure (SO and PP plans only)",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Type.1",
#       "predictions": {
#         "matched_KF_column_1": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Number.1",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Date.1",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Price Currency.1",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Grant Price Per Share/Unit.1",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Accounting Value per Share/Unit of Award.1",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Target Fair Value of Total LTI Granted as % of Base Salary",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Number of Shares/Units Granted.1",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Structure (SO and PP plans only).1",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Type.2",
#       "predictions": {
#         "matched_KF_column_1": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Number.2",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Date.2",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Price Currency.2",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Grant Price Per Share/Unit.2",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Accounting Value per Share/Unit of Award.2",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Target Fair Value of Total LTI Granted as % of Base Salary",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Number of Shares/Units Granted.2",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Structure (SO and PP plans only).2",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Type.3",
#       "predictions": {
#         "matched_KF_column_1": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Long-Term Incentive Plan Number.3",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Date.3",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Price Currency.3",
#       "predictions": {
#         "matched_KF_column_1": "Currency",
#         "matched_KF_column_2": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Grant Price Per Share/Unit.3",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Accounting Value per Share/Unit of Award.3",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Target Fair Value of Total LTI Granted as % of Base Salary",
#         "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#       }
#     },
#     {
#       "input_column": "Number of Shares/Units Granted.3",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     },
#     {
#       "input_column": "Grant Structure (SO and PP plans only).3",
#       "predictions": {
#         "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#         "matched_KF_column_2": "Long-term  Incentive  Eligibility  (Y/N)",
#         "matched_KF_column_3": "Target Fair Value of Total LTI Granted as % of Base Salary"
#       }
#     }
#   ]
# }

# %%
# turn output into JSON object
mapping_results = json.loads(output)
mapping_results = mapping_results['mappings']
type(mapping_results)
# Out:
# list

# %%
# length
len(mapping_results)
# Out:
# 198

# %%
import pandas as pd

df = pd.DataFrame([
    {
        "input_column": item["input_column"],
        "matched_KF_column_1": item["predictions"]["matched_KF_column_1"],
        "matched_KF_column_2": item["predictions"]["matched_KF_column_2"],
        "matched_KF_column_3": item["predictions"]["matched_KF_column_3"]
    }
    for item in mapping_results
])

# optional: save to CSV
version = 'v1'
df.to_csv(f"./../Responses/DF_of_GPT5_Response_{version}.csv", index=False)
