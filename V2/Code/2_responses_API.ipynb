# %% [markdown]
# # Set-Up Code

# %%
OPENAI_API_KEY="*********"
OPENAI_PROJECT="*********"
OPENAI_ORG="*********"

# %%
# from utils.envs import OPENAI_API_KEY
import os
import base64
from typing import List, Dict
from openai import OpenAI
import openai
import glob
import pprint
import tqdm
import numpy as np
import json
import tiktoken
import pandas as pd
import re
import ast
import time
from datetime import datetime

# %% [markdown]
# ### Initialize OpenAI Client

# %%
client = OpenAI(api_key=OPENAI_API_KEY, project=OPENAI_PROJECT, organization=OPENAI_ORG)

# %% [markdown]
# ### Test that I can use Assistants & Responses API

# %%
# test that i can prompt a model

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello! How can I use OpenAI's API to classify job descriptions?"}
    ]
)   

print(response.choices[0].message.content)
# Out:
# To use OpenAI's API for classifying job descriptions, you can leverage the powerful natural language processing capabilities of the API to analyze and classify the text data. Here's a general overview of the steps you can take:
#
# 1. Get an API key: Sign up for access to the OpenAI API on their website and obtain the necessary API key.
#
# 2. Install the OpenAI Python client: You can use the OpenAI Python client to interact with the API. You can install it using pip:
#    ```
#    pip install openai
#    ```
#
# 3. Prepare your job descriptions: Collect or input the job descriptions that you want to classify. Make sure the text data is clean and formatted properly for input to the API.
#
# 4. Make a request to the API: Use the OpenAI Python client to make a classification request to the API. You can use the `classification` endpoint for this purpose. Provide the job description text as the input data along with any relevant parameters for classification.
#
# 5. Receive and interpret the response: The API will return a classification result based on the input job description. The response will typically include the predicted class or category for the job description.
#
# 6. Post-process and utilize the results: You can post-process the classification results as needed, and use them in your applications for various purposes such as job matching, recommendation systems, or data analysis.
#
# Remember to refer to the OpenAI documentation for detailed information on using their API and explore the various capabilities and endpoints available for text classification tasks.

# %%
response = client.responses.create(
    model="gpt-5",
    input = "Hello! How can I use OpenAI's API to classify job descriptions?",
    instructions = "You are a helpful assistant."
)

print(response.output[1].content[0].text)
# Out:
# Great use case. Here’s a practical way to classify job descriptions with OpenAI, with structured JSON output you can trust in code.
#
# High-level approach
# - Define a clear taxonomy (categories, seniority, etc.).
# - Prompt a model with strict instructions and use JSON Schema output so results are machine-parseable.
# - Set temperature to 0 for consistency.
# - Optionally add a few labeled examples to improve accuracy.
#
# Python example (single-label classification)
# - Installs: pip install openai
# - Model: gpt-4.1-mini (good quality/cost for classification)
# - Output: strict JSON matching your schema
#
# ```python
# from openai import OpenAI
# import json
#
# client = OpenAI()
#
# JOB_SCHEMA = {
#   "name": "job_classification",
#   "schema": {
#     "type": "object",
#     "additionalProperties": False,
#     "properties": {
#       "primary_category": {
#         "type": "string",
#         "description": "Best single category for this job.",
#         "enum": [
#           "Software Engineering", "Data Science / ML", "Product Management", "Design / UX",
#           "Sales", "Marketing", "Customer Support / Success", "HR / Talent",
#           "Finance / Accounting", "Operations / Supply Chain", "Legal / Compliance",
#           "IT / Sysadmin / DevOps", "Security", "QA / Testing", "Project / Program Management",
#           "Healthcare", "Education", "Manufacturing", "Construction", "Retail",
#           "Other"
#         ]
#       },
#       "subcategory": { "type": "string", "description": "Optional subcategory label." },
#       "seniority": {
#         "type": "string",
#         "enum": ["Internship", "Junior", "Mid", "Senior", "Lead", "Manager", "Director", "VP", "C-level", "Unspecified"]
#       },
#       "employment_type": {
#         "type": "string",
#         "enum": ["Full-time", "Part-time", "Contract", "Temporary", "Internship", "Unspecified"]
#       },
#       "location_type": {
#         "type": "string",
#         "enum": ["Onsite", "Remote", "Hybrid", "Unspecified"]
#       },
#       "skills": {
#         "type": "array",
#         "items": { "type": "string" },
#         "maxItems": 20
#       },
#       "industry": { "type": "string" },
#       "confidence": { "type": "number", "minimum": 0, "maximum": 1 },
#       "brief_reason": {
#         "type": "string",
#         "description": "Very short rationale (<= 1 sentence)."
#       }
#     },
#     "required": ["primary_category", "confidence"]
#   },
#   "strict": True
# }
#
# def classify_job(jd_text: str) -> dict:
#   instructions = (
#     "You are a job description classifier.\n"
#     "- Choose exactly one primary_category from the enum; use 'Other' only if none fits.\n"
#     "- Base the decision on responsibilities and requirements, not benefits/legal text.\n"
#     "- If multiple roles appear, classify by the role with the most responsibilities.\n"
#     "- Keep brief_reason under 1 sentence."
#     f"\nJob description:\n---\n{jd_text}\n---"
#   )
#
#   resp = client.responses.create(
#     model="gpt-4.1-mini",
#     temperature=0,
#     max_output_tokens=400,
#     response_format={ "type": "json_schema", "json_schema": JOB_SCHEMA },
#     input=instructions
#   )
#
#   # The model returns JSON conforming to the schema.
#   content = resp.output[0].content[0].text
#   return json.loads(content)
#
# # Example
# jd = """We are seeking a Senior Backend Engineer to design and build APIs in Python and Go.
# Experience with PostgreSQL, AWS, Docker, CI/CD. Collaborate with product and frontend teams.
# Full-time, remote-friendly."""
# print(classify_job(jd))
# ```
#
# JavaScript (Node.js) version
# ```javascript
# import OpenAI from "openai";
# const client = new OpenAI();
#
# const JOB_SCHEMA = {
#   name: "job_classification",
#   schema: {
#     type: "object",
#     additionalProperties: false,
#     properties: {
#       primary_category: {
#         type: "string",
#         enum: [
#           "Software Engineering","Data Science / ML","Product Management","Design / UX",
#           "Sales","Marketing","Customer Support / Success","HR / Talent",
#           "Finance / Accounting","Operations / Supply Chain","Legal / Compliance",
#           "IT / Sysadmin / DevOps","Security","QA / Testing","Project / Program Management",
#           "Healthcare","Education","Manufacturing","Construction","Retail","Other"
#         ]
#       },
#       subcategory: { type: "string" },
#       seniority: {
#         type: "string",
#         enum: ["Internship","Junior","Mid","Senior","Lead","Manager","Director","VP","C-level","Unspecified"]
#       },
#       employment_type: {
#         type: "string",
#         enum: ["Full-time","Part-time","Contract","Temporary","Internship","Unspecified"]
#       },
#       location_type: {
#         type: "string",
#         enum: ["Onsite","Remote","Hybrid","Unspecified"]
#       },
#       skills: { type: "array", items: { type: "string" }, maxItems: 20 },
#       industry: { type: "string" },
#       confidence: { type: "number", minimum: 0, maximum: 1 },
#       brief_reason: { type: "string" }
#     },
#     required: ["primary_category","confidence"]
#   },
#   strict: true
# };
#
# async function classifyJob(jdText) {
#   const instructions = `You are a job description classifier.
# - Choose exactly one primary_category from the enum; use 'Other' only if none fits.
# - Base the decision on responsibilities and requirements, not benefits/legal text.
# - If multiple roles appear, classify by the role with the most responsibilities.
# - Keep brief_reason under 1 sentence.
#
# Job description:
# ---
# ${jdText}
# ---`;
#
#   const response = await client.responses.create({
#     model: "gpt-4.1-mini",
#     temperature: 0,
#     max_output_tokens: 400,
#     response_format: { type: "json_schema", json_schema: JOB_SCHEMA },
#     input: instructions
#   });
#
#   const jsonText = response.output[0].content[0].text;
#   return JSON.parse(jsonText);
# }
#
# // Example
# const jd = `Looking for a Senior Product Manager to lead roadmap for B2B SaaS analytics. Collaborate with engineering and design. Experience with data products, stakeholder management.`;
# classifyJob(jd).then(console.log);
# ```
#
# Tips for better accuracy and robustness
# - Define your taxonomy clearly: add short definitions or decision rules for each category in the prompt.
# - Few-shot examples: include 2–5 concise examples of JD → JSON outputs to anchor edge cases.
# - Determinism: temperature 0 and consistent instructions reduce variance.
# - Preprocessing: strip EEO statements, benefits, and company boilerplate to focus on responsibilities/requirements.
# - Long JDs: if very long, first summarize key responsibilities/requirements, then classify the summary to save tokens.
# - Multi-label: if you need multiple categories, change primary_category to categories (array of enums) and specify max labels.
# - Confidence thresholds: decide how to handle low confidence (e.g., route to human review or label as Other).
#
# Scaling and performance
# - Send requests concurrently up to your rate limits; keep per-request tokens small by trimming JDs.
# - For very large taxonomies or very high volume, consider a two-step approach:
#   1) Use embeddings (e.g., text-embedding-3-large) to shortlist likely categories via nearest-neighbor.
#   2) Ask the model to pick the final best label from that shortlist with the JSON schema.
#
# If you share your taxonomy or desired fields, I can tailor the schema and prompt to your exact needs.

# %%
client.vector_stores.list()
# Out:
# SyncCursorPage[VectorStore](data=[VectorStore(id='vs_69025034e2fc81918fdcad91301db0cf', created_at=1761759285, file_counts=FileCounts(cancelled=0, completed=1, failed=0, in_progress=0, total=1), last_active_at=1761759310, metadata={}, name='column_mapper_v1', object='vector_store', status='completed', usage_bytes=9184, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68fdb1fa7e688191a6a4f690441695ea', created_at=1761456634, file_counts=FileCounts(cancelled=0, completed=5, failed=0, in_progress=0, total=5), last_active_at=1761456685, metadata={}, name='job_classifier_GPT_isha', object='vector_store', status='completed', usage_bytes=5282022, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68fba18f05408191853bfea00e219bc4', created_at=1761321359, file_counts=FileCounts(cancelled=0, completed=5, failed=0, in_progress=0, total=5), last_active_at=1761321615, metadata={}, name='job_classifier_gpt_no_aliases', object='vector_store', status='completed', usage_bytes=4355190, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68fb9a22e8cc8191947ee19dd49d417c', created_at=1761319459, file_counts=FileCounts(cancelled=0, completed=5, failed=0, in_progress=0, total=5), last_active_at=1761319864, metadata={}, name='job_classifier_gpt', object='vector_store', status='completed', usage_bytes=5282032, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68f62c38e3348191a93f191cb8b5fc39', created_at=1760963641, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1760963642, metadata={}, name='360-standard Knowledge Base - 2025-10-20T12:34:00.839Z', object='vector_store', status='completed', usage_bytes=1394591, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68f296e26d188191a01d0a4f1019489e', created_at=1760728802, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1760729083, metadata={}, name='kf360_kb_faqs_gpt-4.1_20251017', object='vector_store', status='completed', usage_bytes=1394591, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68e7ad1a0b1c81919cbb4a3763bb5d39', created_at=1760013594, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1760013595, metadata={}, name='360-standard Knowledge Base - 2025-10-09T12:39:53.660Z', object='vector_store', status='completed', usage_bytes=1364978, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68deaf9a2b08819181c2e5d1aca8d6bb', created_at=1759424410, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1759426452, metadata={}, name='kf_360_kb_faqs_gpt-4.1_20251002', object='vector_store', status='completed', usage_bytes=1364978, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68dbf2119b4c8191a6a6c4c7fab3fe6d', created_at=1759244817, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1759244821, metadata={}, name='360-standard Knowledge Base - 2025-09-30T15:06:57.184Z', object='vector_store', status='completed', usage_bytes=1327827, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68dbe052373081919195957a533617b1', created_at=1759240274, file_counts=FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2), last_active_at=1759240278, metadata={}, name='360-standard Knowledge Base - 2025-09-30T13:51:13.750Z', object='vector_store', status='completed', usage_bytes=570762, expires_after=None, expires_at=None, description=None), VectorStore(id='vs_68dab96f93c08191887543dfdcd16619', created_at=1759164783, file_counts=FileCounts(cancelled=0, completed=3, failed=0, in_progress=0, total=3), last_active_at=1759164872, metadata={}, name='kf_360_kb_faqs_gpt-4.1_20250929', object='vector_store', status='completed', usage_bytes=1363852, ex ...

# %% [markdown]
# # Read in Competitor extracted columns

# %%
with open("./../Responses/Extracted_Columns/Argenx_competitor_columns.txt", "r") as f:
    df_comp_columns = [line.strip() for line in f if line.strip()]

print(df_comp_columns)
# Out:
# ['ID', 'Gender', 'Business Title', 'Country', 'argenx job level', 'Currency', 'Actual Annual Salary', 'Currency.1', 'Variable Pay - Plan', 'Target Variable Pay - Percent', 'Allowance - Car', 'Allowance - Phone', 'Allowance - Representation', 'Equity Amount - Annual', 'Cost Center - Name']

# %%
print(len(df_comp_columns))
print(df_comp_columns[:10])
print(df_comp_columns[-10:])
# Out:
# 15
# ['ID', 'Gender', 'Business Title', 'Country', 'argenx job level', 'Currency', 'Actual Annual Salary', 'Currency.1', 'Variable Pay - Plan', 'Target Variable Pay - Percent']
# ['Currency', 'Actual Annual Salary', 'Currency.1', 'Variable Pay - Plan', 'Target Variable Pay - Percent', 'Allowance - Car', 'Allowance - Phone', 'Allowance - Representation', 'Equity Amount - Annual', 'Cost Center - Name']

# %% [markdown]
# # PROMPTING

# %% [markdown]
# ### System Instructions

# %%
system_instructions = f"""
You are an expert data-mapping model trained on Korn Ferry’s column architecture.

You have access to the file `fixed_KF_template.txt`, which contains three columns:
- **KF_Column_Title**: the canonical Korn Ferry column name
- **Description**: a detailed explanation of what that column represents
- **Status**: one of "Required", "Optional", or "If Applicable"

Your task is to map input column names from another dataset to the most semantically similar columns in Korn Ferry’s architecture.

You will receive a list of {len(df_comp_columns)} input column names.

For each input column name, you must:
1. Compare it to all KF_Column_Titles and their Descriptions.
2. Select the **three most relevant Korn Ferry columns** based on meaning, function, or usage similarity.
3. Return your output in **strict JSON format** as follows:

{{
  "input_column": "<input_column_1_name>",
  "predictions": {{
      "matched_KF_column_1": "<prediction_1_of_KF_Column_Title>",
      "matched_KF_column_2": "<prediction_2_of_KF_Column_Title>",
      "matched_KF_column_3": "<prediction_3_of_KF_Column_Title>"
  }},
  "input_column": "<input_column_2_name>",
  "predictions": {{
      "matched_KF_column_1": "<prediction_1_of_KF_Column_Title>",
      "matched_KF_column_2": "<prediction_2_of_KF_Column_Title>",
      "matched_KF_column_3": "<prediction_3_of_KF_Column_Title>"
  }},
  ...
}}

Guidelines:
- Always return **three** matches per input column — no fewer.
- Use both title and description context from Korn Ferry’s architecture to infer matches.
- If unsure, select the closest conceptual matches based on meaning.
- Do **not** include commentary, explanations, or text outside the JSON output.
- Preserve exact spelling and casing of all KF_Column_Title values.
"""

# %%
user_query = f"""
You are given the following {len(df_comp_columns)} input column names that need to be mapped to Korn Ferry’s column architecture:

{df_comp_columns}

Please map each input column to its **three closest** KF_Column_Titles as described in your system instructions.
"""

# %%
print(len(df_comp_columns))
df_comp_columns
# Out:
# 15
# ['ID',
#  'Gender',
#  'Business Title',
#  'Country',
#  'argenx job level',
#  'Currency',
#  'Actual Annual Salary',
#  'Currency.1',
#  'Variable Pay - Plan',
#  'Target Variable Pay - Percent',
#  'Allowance - Car',
#  'Allowance - Phone',
#  'Allowance - Representation',
#  'Equity Amount - Annual',
#  'Cost Center - Name']

# %%
print(system_instructions)
# Out:
# You are an expert data-mapping model trained on Korn Ferry’s column architecture.
#
# You have access to the file `fixed_KF_template.txt`, which contains three columns:
# - **KF_Column_Title**: the canonical Korn Ferry column name
# - **Description**: a detailed explanation of what that column represents
# - **Status**: one of "Required", "Optional", or "If Applicable"
#
# Your task is to map input column names from another dataset to the most semantically similar columns in Korn Ferry’s architecture.
#
# You will receive a list of 15 input column names.
#
# For each input column name, you must:
# 1. Compare it to all KF_Column_Titles and their Descriptions.
# 2. Select the **three most relevant Korn Ferry columns** based on meaning, function, or usage similarity.
# 3. Return your output in **strict JSON format** as follows:
#
# {
#   "input_column": "<input_column_1_name>",
#   "predictions": {
#       "matched_KF_column_1": "<prediction_1_of_KF_Column_Title>",
#       "matched_KF_column_2": "<prediction_2_of_KF_Column_Title>",
#       "matched_KF_column_3": "<prediction_3_of_KF_Column_Title>"
#   },
#   "input_column": "<input_column_2_name>",
#   "predictions": {
#       "matched_KF_column_1": "<prediction_1_of_KF_Column_Title>",
#       "matched_KF_column_2": "<prediction_2_of_KF_Column_Title>",
#       "matched_KF_column_3": "<prediction_3_of_KF_Column_Title>"
#   },
#   ...
# }
#
# Guidelines:
# - Always return **three** matches per input column — no fewer.
# - Use both title and description context from Korn Ferry’s architecture to infer matches.
# - If unsure, select the closest conceptual matches based on meaning.
# - Do **not** include commentary, explanations, or text outside the JSON output.
# - Preserve exact spelling and casing of all KF_Column_Title values.

# %%
print(user_query)
# Out:
# You are given the following 15 input column names that need to be mapped to Korn Ferry’s column architecture:
#
# ['ID', 'Gender', 'Business Title', 'Country', 'argenx job level', 'Currency', 'Actual Annual Salary', 'Currency.1', 'Variable Pay - Plan', 'Target Variable Pay - Percent', 'Allowance - Car', 'Allowance - Phone', 'Allowance - Representation', 'Equity Amount - Annual', 'Cost Center - Name']
#
# Please map each input column to its **three closest** KF_Column_Titles as described in your system instructions.

# %% [markdown]
# # Testing the prompts

# %%
start_time = time.time()
response_0 = client.responses.create(input=user_query,
                                    instructions=system_instructions,
                                    model="gpt-5",
                                    tools=[{"type": "file_search",
                                            "vector_store_ids": ["vs_69025034e2fc81918fdcad91301db0cf"],
                                            }]
                                    )
end_time = time.time()

# %%
latency = end_time - start_time
print(f"Response time: {latency} seconds")
# Out:
# Response time: 147.80661606788635 seconds

# %%
# write latency to .txt file

with open("./../Responses/Latency/Argenx_predictions_latency.txt", "w") as f:
    f.write(f'Response time: {latency} seconds')
    f.write('\n')
    f.write(f'Mapped {len(df_comp_columns)} columns')

# %%
output = response_0.output[-1].content[-1].text
print(type(output))
print(output)
# Out:
# <class 'str'>
# [
#   {
#     "input_column": "ID",
#     "predictions": {
#       "matched_KF_column_1": "Employee ID",
#       "matched_KF_column_2": "Manager Employee  ID",
#       "matched_KF_column_3": "Korn Ferry Reference  Job Code"
#     }
#   },
#   {
#     "input_column": "Gender",
#     "predictions": {
#       "matched_KF_column_1": "Gender",
#       "matched_KF_column_2": "Executive/Non-Executive Indicator (E / N)",
#       "matched_KF_column_3": "Expat"
#     }
#   },
#   {
#     "input_column": "Business Title",
#     "predictions": {
#       "matched_KF_column_1": "Employee  Job Title",
#       "matched_KF_column_2": "Department",
#       "matched_KF_column_3": "Legal Entity / Business Unit"
#     }
#   },
#   {
#     "input_column": "Country",
#     "predictions": {
#       "matched_KF_column_1": "Country",
#       "matched_KF_column_2": "Employee Work Location / Zip/Postal Code",
#       "matched_KF_column_3": "Legal Entity / Business Unit"
#     }
#   },
#   {
#     "input_column": "argenx job level",
#     "predictions": {
#       "matched_KF_column_1": "Employee  Grade / Band",
#       "matched_KF_column_2": "Korn Ferry Reference Level   (not required if Ref. Job Code is provided in Column O)",
#       "matched_KF_column_3": "Korn Ferry Total Points"
#     }
#   },
#   {
#     "input_column": "Currency",
#     "predictions": {
#       "matched_KF_column_1": "Currency",
#       "matched_KF_column_2": "Country",
#       "matched_KF_column_3": "Basic Payments (Annual full-time equivalent)"
#     }
#   },
#   {
#     "input_column": "Actual Annual Salary",
#     "predictions": {
#       "matched_KF_column_1": "Basic Payments (Annual full-time equivalent)",
#       "matched_KF_column_2": "Fixed Payments (Annual full-time equivalent)",
#       "matched_KF_column_3": "Salary Structure Midpoint"
#     }
#   },
#   {
#     "input_column": "Currency.1",
#     "predictions": {
#       "matched_KF_column_1": "Currency",
#       "matched_KF_column_2": "Basic Payments (Annual full-time equivalent)",
#       "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#     }
#   },
#   {
#     "input_column": "Variable Pay - Plan",
#     "predictions": {
#       "matched_KF_column_1": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#       "matched_KF_column_2": "Short-term Variable Payment (Annual full-time equivalent)",
#       "matched_KF_column_3": "Target Short-term Variable Payment  (% of Base Salary)"
#     }
#   },
#   {
#     "input_column": "Target Variable Pay - Percent",
#     "predictions": {
#       "matched_KF_column_1": "Target Short-term Variable Payment  (% of Base Salary)",
#       "matched_KF_column_2": "Short-term  Variable  Payment  Eligibility  (Y/N)",
#       "matched_KF_column_3": "Short-term Variable Payment (Annual full-time equivalent)"
#     }
#   },
#   {
#     "input_column": "Allowance - Car",
#     "predictions": {
#       "matched_KF_column_1": "Car Allowance (Annual full-time equivalent)",
#       "matched_KF_column_2": "Car Eligibility  (Y/N)",
#       "matched_KF_column_3": "Transportation / Commuting Allowance (Annual full-time equivalent)"
#     }
#   },
#   {
#     "input_column": "Allowance - Phone",
#     "predictions": {
#       "matched_KF_column_1": "Telecommunication Allowance (Annual full-time equivalent)",
#       "matched_KF_column_2": "All Other Allowances (Annual full-time equivalent)",
#       "matched_KF_column_3": "Other Benefits and Allowances (Annual full-time equivalent)"
#     }
#   },
#   {
#     "input_column": "Allowance - Representation",
#     "predictions": {
#       "matched_KF_column_1": "All Other Allowances (Annual full-time equivalent)",
#       "matched_KF_column_2": "Other Benefits and Allowances (Annual full-time equivalent)",
#       "matched_KF_column_3": "Meal Allowance (Annual full-time equivalent)"
#     }
#   },
#   {
#     "input_column": "Equity Amount - Annual",
#     "predictions": {
#       "matched_KF_column_1": "Actual Fair Value of Total LTI Granted",
#       "matched_KF_column_2": "Target Fair Value of Total LTI Granted as % of Base Salary",
#       "matched_KF_column_3": "Long-term  Incentive  Eligibility  (Y/N)"
#     }
#   },
#   {
#     "input_column": "Cost Center - Name",
#     "predictions": {
#       "matched_KF_column_1": "Department",
#       "matched_KF_column_2": "Legal Entity / Business Unit",
#       "matched_KF_column_3": "Function Code  (not required if Ref. Job Code is provided  in column O)"
#     }
#   }
# ]

# %%
# turn output into JSON object
mapping_results = json.loads(output)
type(mapping_results)
# Out:
# list

# %%
# length
len(mapping_results)
# Out:
# 15

# %%
import pandas as pd

df = pd.DataFrame([
    {
        "input_column": item["input_column"],
        "matched_KF_column_1": item["predictions"]["matched_KF_column_1"],
        "matched_KF_column_2": item["predictions"]["matched_KF_column_2"],
        "matched_KF_column_3": item["predictions"]["matched_KF_column_3"]
    }
    for item in mapping_results
])

df.head()
# Out:
#        input_column     matched_KF_column_1  \
# 0                ID             Employee ID
# 1            Gender                  Gender
# 2    Business Title     Employee  Job Title
# 3           Country                 Country
# 4  argenx job level  Employee  Grade / Band
#
#                                  matched_KF_column_2  \
# 0                               Manager Employee  ID
# 1          Executive/Non-Executive Indicator (E / N)
# 2                                         Department
# 3           Employee Work Location / Zip/Postal Code
# 4  Korn Ferry Reference Level   (not required if ...
#
#               matched_KF_column_3
# 0  Korn Ferry Reference  Job Code
# 1                           Expat
# 2    Legal Entity / Business Unit
# 3    Legal Entity / Business Unit
# 4         Korn Ferry Total Points

# %%
df.tail()
# Out:
#                   input_column  \
# 10             Allowance - Car
# 11           Allowance - Phone
# 12  Allowance - Representation
# 13      Equity Amount - Annual
# 14          Cost Center - Name
#
#                                   matched_KF_column_1  \
# 10        Car Allowance (Annual full-time equivalent)
# 11  Telecommunication Allowance (Annual full-time ...
# 12  All Other Allowances (Annual full-time equival...
# 13             Actual Fair Value of Total LTI Granted
# 14                                         Department
#
#                                   matched_KF_column_2  \
# 10                             Car Eligibility  (Y/N)
# 11  All Other Allowances (Annual full-time equival...
# 12  Other Benefits and Allowances (Annual full-tim...
# 13  Target Fair Value of Total LTI Granted as % of...
# 14                       Legal Entity / Business Unit
#
#                                   matched_KF_column_3
# 10  Transportation / Commuting Allowance (Annual f...
# 11  Other Benefits and Allowances (Annual full-tim...
# 12       Meal Allowance (Annual full-time equivalent)
# 13           Long-term  Incentive  Eligibility  (Y/N)
# 14  Function Code  (not required if Ref. Job Code ...

# %%
# save to CSV
df.to_csv(f"./../Responses/Predictions/Argenx_GPT5_predictions.csv", index=False)
